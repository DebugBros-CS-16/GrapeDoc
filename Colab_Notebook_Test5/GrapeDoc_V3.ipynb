# %%
# %matplotlib inline

import os

#if using Theano with GPU
#os.environ["KERAS_BACKEND"] = "tensorflow"

import random
import numpy as np
import keras

import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

from keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
from keras.layers import Conv2D, MaxPooling2D
from keras.models import Model

# %%
root = '/content/drive/MyDrive/GrapeDoc_Dataset'
exclude = ['valid']
train_split, val_split = 0.7, 0.15

categories = [x[0] for x in os.walk(root) if x[0]][1:]
categories = [c for c in categories if c not in [os.path.join(root, e) for e in exclude]]

print(categories)
# Out:
# ['/content/drive/MyDrive/GrapeDoc_Dataset/train', '/content/drive/MyDrive/GrapeDoc_Dataset/train/Grape___healthy', '/content/drive/MyDrive/GrapeDoc_Dataset/train/Grape___Esca_(Black_Measles)', '/content/drive/MyDrive/GrapeDoc_Dataset/train/Grape___Black_rot', '/content/drive/MyDrive/GrapeDoc_Dataset/train/Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', '/content/drive/MyDrive/GrapeDoc_Dataset/valid/Validation_Images', '/content/drive/MyDrive/GrapeDoc_Dataset/test', '/content/drive/MyDrive/GrapeDoc_Dataset/test/Grape___Black_rot', '/content/drive/MyDrive/GrapeDoc_Dataset/test/Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', '/content/drive/MyDrive/GrapeDoc_Dataset/test/Grape___Esca_(Black_Measles)', '/content/drive/MyDrive/GrapeDoc_Dataset/test/Grape___healthy']

# %%
# helper function to load image and return it and input vector
def get_image(path):
    img = image.load_img(path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    return img, x

# %%
data = []
for c, category in enumerate(categories):
    images = [os.path.join(dp, f) for dp, dn, filenames 
              in os.walk(category) for f in filenames 
              if os.path.splitext(f)[1].lower() in ['.jpg','.png','.jpeg']]
    for img_path in images:
        img, x = get_image(img_path)
        data.append({'x':np.array(x[0]), 'y':c})

# count the number of classes
num_classes = len(categories)

# %%
random.shuffle(data)

# %%
idx_val = int(train_split * len(data))
idx_test = int((train_split + val_split) * len(data))
train = data[:idx_val]
val = data[idx_val:idx_test]
test = data[idx_test:]

# %%
x_train, y_train = np.array([t["x"] for t in train]), [t["y"] for t in train]
x_val, y_val = np.array([t["x"] for t in val]), [t["y"] for t in val]
x_test, y_test = np.array([t["x"] for t in test]), [t["y"] for t in test]
print(y_test)
